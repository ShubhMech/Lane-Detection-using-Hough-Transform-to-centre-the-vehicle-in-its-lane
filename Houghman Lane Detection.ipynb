# %%
import numpy as np, cv2, matplotlib.pyplot as plt, matplotlib.image as img_

# %%
img= img_.imread(r"D:\Asus\Documents\abstract-hipster-lines-background-vector-260nw-344953271.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (280, 260, 3)

# %%
line_x= np.array([[-1,2,-1],[0,0,0],[1,2,1]])

# %%
x_sobel=cv2.Sobel(img,cv2.CV_64F,0,1,ksize=9)

# %%
plt.imshow(x_sobel,cmap="gray")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
sobel= np.array([[-1,-2,-1],[0,0,0],[1,2,1]])

# %%
sobel_y=np.transpose(sobel)

# %%
sobel_x= cv2.filter2D(img, -1, sobel)

# %%
plt.imshow(sobel_x)

# %%
sobel_y= cv2.filter2D(img, -1, sobel_y)

# %%
plt.imshow(sobel_y)

# %%
plt.imshow(cv2.Canny(img, 120,200))

# %%
canny=cv2.Canny(img, 120,200)

# %%
lines= cv2.HoughLines(canny,1,np.pi/180,100)

# %%
len(lines)
# Out:
# 60

# %%
lines
# Out:
# array([[[ 2.2800000e+02,  0.0000000e+00]],
#
#        [[ 2.3000000e+02,  0.0000000e+00]],
#
#        [[ 2.2200000e+02,  0.0000000e+00]],
#
#        [[ 2.2000000e+02,  0.0000000e+00]],
#
#        [[ 2.1300000e+02,  0.0000000e+00]],
#
#        [[ 2.1500000e+02,  0.0000000e+00]],
#
#        [[ 2.0600000e+02,  0.0000000e+00]],
#
#        [[ 2.0800000e+02,  0.0000000e+00]],
#
#        [[ 1.5800000e+02,  1.5707964e+00]],
#
#        [[ 1.5500000e+02,  1.5707964e+00]],
#
#        [[ 2.0000000e+02,  0.0000000e+00]],
#
#        [[ 1.6200000e+02,  1.5707964e+00]],
#
#        [[ 1.6600000e+02,  1.5707964e+00]],
#
#        [[ 1.7300000e+02,  1.5707964e+00]],
#
#        [[ 1.7000000e+02,  1.5707964e+00]],
#
#        [[ 1.9800000e+02,  0.0000000e+00]],
#
#        [[ 1.5100000e+02,  1.5707964e+00]],
#
#        [[ 1.7700000e+02,  1.5707964e+00]],
#
#        [[ 1.8000000e+02,  1.5707964e+00]],
#
#        [[ 1.9100000e+02,  0.0000000e+00]],
#
#        [[ 1.4700000e+02,  1.5707964e+00]],
#
# ...
